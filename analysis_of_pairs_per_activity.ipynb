# %%
# %load_ext autoreload
# %autoreload 1

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", 'This pattern has match groups')
# %matplotlib inline
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 60
pd.options.display.max_colwidth = 200

# %%
#utils.py is where all our custom functions live is we set an autoreload on it.
# %aimport utils 
from utils import *
# %aimport viz_utils 
from viz_utils import *

# %% [markdown]
# # Loading the data

# %%
df_all = pd.read_excel('all data v3.xlsx', 'iLab data.txt', index_col=None, na_values=['NA'])

# %% [markdown]
# # Plotting the 9 pairs for analysis; condition trampoline
# Along with the time coordinates of the ideas they had (i.e. their methods before a delete all or a submit)
#
# Note: students may have used a method multiple times, only the 1st time coordinate when the method was deleted/submitted is shown for simplicity.

# %%
# %aimport viz_utils
# %aimport utils
session_pairs = ["L70970875:120f77e742b:-8000",
    "L-32a989cf:120ecd7e93b:-8000",
    "L40bb98dd:120c3a7683a:-8000",
    "L-7821f52f:120f7fb42ba:-8000",
    "L651ef9df:120f7fb65f2:-8000",
    "L46c6b7c:120ed2665a4:-8000",
    "L-10f11766:120ecd4f63a:-8000",
    "L-160920ae:120ed3b11b6:-8000",
    "L-2567b17a:120eda25685:-8000"]

for session in session_pairs:
    print "Student Pair:", session
    df = prepare_session(df_all,session)
    plot(df,to_plot,colors, column_to_use, function_to_use)
    ideas = get_key_ideas(df)
    print "\n"
    display(ideas)
    print "\n\n\n-------------------------------------------------------"
# Out:
# Student Pair: L70970875:120f77e742b:-8000
#                action timestamp                  cases  \
# 0  ** get new case **     0m 0s                      -
# 1              delete   12m 44s  1 3 5 7 9 | 3 4 5 6 7
# 2              submit   14m 34s  1 3 5 7 9 | 3 4 5 6 7
# 3              submit   15m 53s  1 3 5 7 9 | 3 4 5 6 7
# 4              submit   21m 33s  1 3 5 7 9 | 3 4 5 6 7
# 5              submit   24m 40s  1 3 5 7 9 | 3 4 5 6 7
# 6              submit   26m 46s  1 3 5 7 9 | 3 4 5 6 7
#
#                          tried methods
# 0                                    -
# 1       st1 Sum all  | st1 Count all +
# 2    st1 Median all  | st1 Median all
# 3  st1 Average all  | st1 Average all
# 4  st1 Average all  | st1 Average all
# 5    st1 - Median  | st1 - Median all
# 6  st1 Average all  | st1 Average all
# -------------------------------------------------------
# Student Pair: L-32a989cf:120ecd7e93b:-8000
#                 action timestamp                  cases  \
# 0   ** get new case **     0m 0s                      -
# 1               delete    1m 45s  1 3 5 7 9 | 3 4 5 6 7
# 2               delete    5m 30s  1 3 5 7 9 | 3 4 5 6 7
# 3            deleteAll    5m 54s  1 3 5 7 9 | 3 4 5 6 7
# 4               delete    7m 15s  1 3 5 7 9 | 3 4 5 6 7
# 5               delete    9m 18s  1 3 5 7 9 | 3 4 5 6 7
# 6               submit    9m 45s  1 3 5 7 9 | 3 4 5 6 7
# 7   ** get new case **   11m 54s                      -
# 8            deleteAll   14m 48s    2 5 8 | 2 2 5 5 8 8
# 9               delete    18m 8s    2 5 8 | 2 2 5 5 8 8
# 10           deleteAll   21m 37s    2 5 8 | 2 2 5 5 8 8
# 11           deleteAll   23m 45s    2 5 8 | 2 2 5 5 8 8
# 12           deleteAll    28m 4s    2 5 8 | 2 2 5 5 8 8
# 13           deleteAll   29m 15s    2 5 8 | 2 2 5 5 8 8
# 14           deleteAll    33m 1s    2 5 8 | 2 2 5 5 8 8
#
#                                                                                 tried methods
# 0                                                                                           -
# 1                                                                      st1 Average all  | st1
# 2                                                                    st1 Median all + 5 | st1
# 3                                                               st1 Count choose... 5 9 | st1
# 4   st1 Median all x Average choose... 7 9 3 1  | st1 Median all x Average choose... 7 6 4 3
# 5                                                st1 Sum all + Average 1 3  | st1 Sum all + 3
# 6                                     st1 Sum all + Average 1 3  | st1 Sum all + Average 3 4
# 7                                                                                           -
# 8                                     st1 Sum all + Average 2 5  | st1 Sum all + Average 2 2
# 9                                        st1 Count 2 5 x Count 8  | st1 Count choose... 2 2 5
# 10                            st1 Count 2 5 x Count 8  | st1 Count choose... 2 2 x Count 2 8
# 11                                        st1 Count 2 5 x Count 8  | st1 Count 2 2 x Count 8
# 12                                  st1 Median all / Count all  | st1 Median all / Count all
# 13                                st1 Median all / Count all  | st1 Median all / Count 2 5 8
# 14                st1 Sum all + Median all st2 Step1 x | st1 Sum all + Median all st2 Step1 x
# -------------------------------------------------------
# Student Pair: L40bb98dd:120c3a7683a:-8000
#                 action timestamp                  cases  \
# 0   ** get new case **     0m 0s                      -
# 1               delete    0m 56s  1 3 5 7 9 | 3 4 5 6 7
# 2            deleteAll     1m 9s  1 3 5 7 9 | 3 4 5 6 7
# 3               delete    9m 13s  1 3 5 7 9 | 3 4 5 6 7
# 4               submit    10m 9s  1 3 5 7 9 | 3 4 5 6 7
# 5   ** get new case **   10m 45s                      -
# 6               delete   12m 38s    2 5 8 | 2 2 5 5 8 8
# 7               submit    13m 3s    2 5 8 | 2 2 5 5 8 8
# 8               delete   14m 23s    2 5 8 | 2 2 5 5 8 8
# 9               delete    16m 3s    2 5 8 | 2 2 5 5 8 8
# 10              submit   16m 18s    2 5 8 | 2 2 5 5 8 8
# 11  ** get new case **   22m 46s                      -
#
#                                                                                                               tried methods
# 0                                                                                                                         -
# 1                                                                                                   st1 9 + 7 st2 5 | st1 7
# 2                                                                                                         st1 9 + 7 | st1 7
# 3                           st1 9 + 7 st2 Step1 + 3 st3 Step2 + 1 st4 Step3 / | st1 6 + 7 st2 Step1 + 5 st3 Step2 + 4 st4 3
# 4     st1 9 + 7 st2 Step1 + 3 st3 Step2 + 1 st4 Step3 / | st1 6 + 7 st2 Step1 + 5 st3 Step2 + 4 st4 Step3 + 3 st5 Step4 / 5
# 5                                                                                                                         -
# 6                                             st1 8 + 5 st2 Step1 + 2 | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 5
# 7                               st1 8 + 5 st2 Step1 + 2 | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 2 st5 Step4 + 2
# 8               st1 8 + 5 st2 Step1 + 2 st3 | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 2 st5 Step4 + 2 st6 Step5 /
# 9         st1 8 + 5 st2 Step1 + 2 st3 5 / | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 2 st5 Step4 + 2 st6 Step5 / 5
# 10  st1 8 + 5 st2 Step1 + 2 st3 Step2 / 5 | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 2 st5 Step4 + 2 st6 Step5 / 5
# 11                                                                                                                        -
# -------------------------------------------------------
# Student Pair: L-7821f52f:120f7fb42ba:-8000
#                 action timestamp                  cases  \
# 0   ** get new case **     0m 0s                      -
# 1               delete    1m 48s  1 3 5 7 9 | 3 4 5 6 7
# 2               delete    2m 17s  1 3 5 7 9 | 3 4 5 6 7
# 3               delete    2m 42s  1 3 5 7 9 | 3 4 5 6 7
# 4            deleteAll     5m 9s  1 3 5 7 9 | 3 4 5 6 7
# 5               delete    9m 49s  1 3 5 7 9 | 3 4 5 6 7
# 6               delete   10m 42s  1 3 5 7 9 | 3 4 5 6 7
# 7               delete   19m 24s  1 3 5 7 9 | 3 4 5 6 7
# 8               delete   22m 27s  1 3 5 7 9 | 3 4 5 6 7
# 9               delete   23m 17s  1 3 5 7 9 | 3 4 5 6 7
# 10              delete   24m 39s  1 3 5 7 9 | 3 4 5 6 7
# 11           deleteAll   25m 15s  1 3 5 7 9 | 3 4 5 6 7
#
#                                                                                                                                                                                               tried methods
# 0                                                                                                                                                                                                         -
# 1                                                                                                                                                                                        st1 Sum 1 3  | st1
# 2                                                                                                                                                                                  st1 Average 7 3  | st1 7
# 3                                                                                                                                                                                  st1 Average all  | st1 7
# 4                                                                                                                            st1 Average all x 9 st2 Average all x 5 | st1 Average all x 7 st2 Average all
# 5                                         st1 Average all x 5 st2 Average all x 9 st3 Average all x 1 st4 Average all x 7 | st1 Average all x 6 st2 Average all x 7 st3 Sum all x 5 st4 Average all x Step3
# 6                                                                             st1 Average all x 5 st2 Average all x 9 st3 Average all x 1 st4 Average all x 7 | st1 Average all x 6 st2 Average all x 7 st3
# 7                                    st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 st4 Average all x 3 st5 | st1 Average all x 3 st2 Average all x 5 st3 Average all x 4 st4 Average all
# 8   st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 st4 Average all x 3 st5 Average all - 7 st6 Average all - 1 st7 Step1 - Step5 st8 | st1 Average all x 3 st2 Average all x 5 st3 Aver...
# 9   st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 st4 Average all x 3 st5 Average all - 7 st6 Average all - 1 st7 Step1 - Step5 st8 | st1 Average all x 3 st2 Average all x 5 st3 Aver...
# 10  st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 st4 Average all x 3 st5 Average all - 7 st6 Average all - 1 st7 Step1 - Step5 st8 Average all - 7 | st1 Average all x 3 st2 Average ...
# 11  st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 | st1 Average all x 3 st2 Average all x 5 st3 Average all x 4 st4 Average all - 5 st5 Average all - 7 st6 Average all - 6 st7 Averag...
# -------------------------------------------------------
# Student Pair: L651ef9df:120f7fb65f2:-8000
#                 action timestamp                  cases  \
# 0   ** get new case **     0m 0s                      -
# 1               delete    0m 52s  1 3 5 7 9 | 3 4 5 6 7
# 2            deleteAll    1m 17s  1 3 5 7 9 | 3 4 5 6 7
# 3               delete    2m 31s  1 3 5 7 9 | 3 4 5 6 7
# 4               delete    2m 59s  1 3 5 7 9 | 3 4 5 6 7
# 5               delete     4m 6s  1 3 5 7 9 | 3 4 5 6 7
# 6               delete    8m 22s  1 3 5 7 9 | 3 4 5 6 7
# 7               delete    8m 39s  1 3 5 7 9 | 3 4 5 6 7
# 8               delete    9m 26s  1 3 5 7 9 | 3 4 5 6 7
# 9               delete   10m 16s  1 3 5 7 9 | 3 4 5 6 7
# 10              delete   10m 44s  1 3 5 7 9 | 3 4 5 6 7
# 11           deleteAll   10m 58s  1 3 5 7 9 | 3 4 5 6 7
# 12           deleteAll   11m 31s  1 3 5 7 9 | 3 4 5 6 7
# 13           deleteAll    12m 3s  1 3 5 7 9 | 3 4 5 6 7
# 14           deleteAll   12m 22s  1 3 5 7 9 | 3 4 5 6 7
# 15           deleteAll    13m 7s  1 3 5 7 9 | 3 4 5 6 7
# 16           deleteAll   13m 30s  1 3 5 7 9 | 3 4 5 6 7
# 17           deleteAll   13m 46s  1 3 5 7 9 | 3 4 5 6 7
# 18           deleteAll   15m 45s  1 3 5 7 9 | 3 4 5 6 7
# 19              submit   17m 19s  1 3 5 7 9 | 3 4 5 6 7
# 20              submit   20m 32s  1 3 5 7 9 | 3 4 5 6 7
# 21  ** get new case **   20m 56s                      -
# 22           deleteAll    22m 4s  1 3 5 7 9 | 1 4 5 6 9
# 23           deleteAll   22m 26s  1 3 5 7 9 | 1 4 5 6 9
# 24           deleteAll   22m 38s  1 3 5 7 9 | 1 4 5 6 9
# 25           deleteAll   22m 57s  1 3 5 7 9 | 1 4 5 6 9
# 26           deleteAll   23m 42s  1 3 5 7 9 | 1 4 5 6 9
# 27           deleteAll   24m 14s  1 3 5 7 9 | 1 4 5 6 9
#
#                           tried methods
# 0                                     -
# 1                         st1 1 + | st1
# 2                       st1 1 + 1 | st1
# 3                           st1 1 | st1
# 4                    st1 Sum all  | st1
# 5   st1 Average all  | st1 Average all
# 6                  st1 Count all  | st1
# 7        st1 Count all  | st1 Count all
# 8               st1 Average none  | st1
# 9                st1 Average all  | st1
# 10       st1 9 x 5 st2 Count all  | st1
# 11                      st1 9 x 9 | st1
# 12    st1 Median all  | st1 Median all
# 13          st1 Sum all  | st1 Sum all
# 14        st1 Count all  | st1 Sum all
# 15      st1 Average | st1 Average none
# 16  st1 Average all  | st1 Average all
# 17    st1 Median all  | st1 Median all
# 18                st1 9 - 1 | st1 7 - 4
# 19                st1 9 - 1 | st1 7 - 3
# 20                st1 9 - 1 | st1 7 - 3
# 21                                    -
# 22                st1 9 - 1 | st1 9 - 1
# 23  st1 Average all  | st1 Average all
# 24        st1 Count all | st1 Count all
# 25            st1 Sum all | st1 Sum all
# 26       st1 Median all  | st1 Sum all
# 27    st1 Median all  | st1 Median all
# -------------------------------------------------------
# Student Pair: L46c6b7c:120ed2665a4:-8000
#                 action timestamp                  cases  \
# 0   ** get new case **     0m 0s                      -
# 1            deleteAll    3m 28s  1 3 5 7 9 | 3 4 5 6 7
# 2            deleteAll    5m 18s  1 3 5 7 9 | 3 4 5 6 7
# 3            deleteAll    6m 23s  1 3 5 7 9 | 3 4 5 6 7
# 4            deleteAll    6m 58s  1 3 5 7 9 | 3 4 5 6 7
# 5            deleteAll    7m 14s  1 3 5 7 9 | 3 4 5 6 7
# 6               delete    7m 35s  1 3 5 7 9 | 3 4 5 6 7
# 7            deleteAll    8m 16s  1 3 5 7 9 | 3 4 5 6 7
# 8               submit    8m 43s  1 3 5 7 9 | 3 4 5 6 7
# 9            deleteAll    9m 28s  1 3 5 7 9 | 3 4 5 6 7
# 10           deleteAll    9m 54s  1 3 5 7 9 | 3 4 5 6 7
# 11           deleteAll    10m 6s  1 3 5 7 9 | 3 4 5 6 7
# 12              submit   10m 34s  1 3 5 7 9 | 3 4 5 6 7
# 13           deleteAll   11m 44s  1 3 5 7 9 | 3 4 5 6 7
# 14           deleteAll   12m 30s  1 3 5 7 9 | 3 4 5 6 7
# 15           deleteAll   13m 40s  1 3 5 7 9 | 3 4 5 6 7
# 16              submit   15m 16s  1 3 5 7 9 | 3 4 5 6 7
# 17  ** get new case **    16m 4s                      -
# 18              submit   16m 54s  1 3 5 7 9 | 1 4 5 6 9
# 19           deleteAll   19m 47s  1 3 5 7 9 | 1 4 5 6 9
# 20           deleteAll   19m 59s  1 3 5 7 9 | 1 4 5 6 9
# 21              submit   20m 45s  1 3 5 7 9 | 1 4 5 6 9
# 22              submit   23m 24s  1 3 5 7 9 | 1 4 5 6 9
# 23           deleteAll   24m 20s  1 3 5 7 9 | 1 4 5 6 9
# 24              submit   24m 47s  1 3 5 7 9 | 1 4 5 6 9
# 25           deleteAll   25m 37s  1 3 5 7 9 | 1 4 5 6 9
# 26              submit   26m 26s  1 3 5 7 9 | 1 4 5 6 9
# 27              submit    31m 3s  1 3 5 7 9 | 1 4 5 6 9
#
#                                              tried methods
# 0                                                        -
# 1                st1 Average choose... Median all  | st1 3
# 2                              st1 Sum all / 5 st2 | st1 3
# 3   st1 Sum all / 5 st2 | st1 Count choose... Median all x
# 4                   st1 Sum all / 5 st2 | st1 Median all x
# 5                              st1 Sum all / 5 st2 | st1 5
# 6                 st1 Sum all / 5 st2 | st1 Median all x 5
# 7                    st1 Sum all / 5 st2 | st1 Sum all / 5
# 8                        st1 Sum all / 5 | st1 Sum all / 5
# 9                    st1 Count choose... | st1 Sum all / 5
# 10                       st1 Count all x | st1 Sum all / 5
# 11                               st1 Sum | st1 Sum all / 5
# 12                       st1 Sum all / 5 | st1 Sum all / 5
# 13                   st1 Average all x 3 | st1 Sum all / 5
# 14                       st1 Sum all - 9 | st1 Sum all / 5
# 15                        st1 Count all  | st1 Sum all / 5
# 16                    st1 Count 2 4 6 8  | st1 Count none
# 17                                                       -
# 18                 st1 Count 2 4 6 8  | st1 Count 3 2 8 7
# 19                                st1 Count 2 4 6 8  | st1
# 20                                     st1 Average 1 | st1
# 21               st1 Average choose... 4  | st1 Average 4
# 22                 st1 Count 2 4 6 8  | st1 Count 2 3 7 8
# 23                                       st1 Sum all | st1
# 24                       st1 Median all  | st1 Median all
# 25                                 st1 Sum 2 4 8 6 6 | st1
# 26               st1 Sum 4 6 8 2 / 5 | st1 Sum 7 8 3 2 / 5
# 27                     st1 Count 3 5 7  | st1 Count 4 5 6
# -------------------------------------------------------
# Student Pair: L-10f11766:120ecd4f63a:-8000
#                 action timestamp                  cases  \
# 0   ** get new case **     0m 0s                      -
# 1            deleteAll    7m 50s  1 3 5 7 9 | 3 4 5 6 7
# 2            deleteAll   10m 16s  1 3 5 7 9 | 3 4 5 6 7
# 3            deleteAll   10m 32s  1 3 5 7 9 | 3 4 5 6 7
# 4            deleteAll   12m 19s  1 3 5 7 9 | 3 4 5 6 7
# 5            deleteAll   13m 45s  1 3 5 7 9 | 3 4 5 6 7
# 6            deleteAll    16m 2s  1 3 5 7 9 | 3 4 5 6 7
# 7               submit   20m 55s  1 3 5 7 9 | 3 4 5 6 7
# 8   ** get new case **   21m 15s                      -
# 9               submit    22m 7s  1 3 5 7 9 | 1 4 5 6 9
# 10           deleteAll   25m 20s  1 3 5 7 9 | 1 4 5 6 9
# 11              submit   25m 59s  1 3 5 7 9 | 1 4 5 6 9
# 12              submit   27m 11s  1 3 5 7 9 | 1 4 5 6 9
# 13           deleteAll   29m 38s  1 3 5 7 9 | 1 4 5 6 9
# 14           deleteAll   30m 56s  1 3 5 7 9 | 1 4 5 6 9
# 15           deleteAll   31m 10s  1 3 5 7 9 | 1 4 5 6 9
# 16           deleteAll   31m 18s  1 3 5 7 9 | 1 4 5 6 9
# 17              delete   31m 48s  1 3 5 7 9 | 1 4 5 6 9
# 18              delete    36m 8s  1 3 5 7 9 | 1 4 5 6 9
#
#                                                            tried methods
# 0                                                                      -
# 1                          st1 Average all / | st1 Average all / Average
# 2                                      st1 Median all  | st1 Median all
# 3                                        st1 Count all  | st1 Count all
# 4                                st1 Sum all / Count all  | st1 Sum all
# 5           st1 Average all / Median all | st1 Average all / Median all
# 6                                                  st1 Count all + | st1
# 7                                   st1 Count 2 4 6 8  | st1 Count none
# 8                                                                      -
# 9                                st1 Count 2 6 4 8  | st1 Count 3 2 7 8
# 10                                                           st1 2 | st1
# 11                               st1 Count 2 6 4 8  | st1 Count 3 2 7 8
# 12                               st1 Sum 1 3 5 7 9  | st1 Sum 1 4 5 6 9
# 13                   st1 Count choose... 2 4 6 8 + | st1 Sum 1 4 5 6 9 +
# 14             st1 Count choose... 2 4 6 8 + | st1 Count choose... 2 3 3
# 15                       st1 Count choose... 2 4 6 8 + | st1 Count 2 3 2
# 16                             st1 Count choose... 2 4 6 8 + | st1 Count
# 17                       st1 Count choose... 2 4 6 8 + | st1 Count 2 3 7
# 18  st1 Count choose... 2 4 6 8 - Count 1 3 5 7 9  | st1 Count 2 3 7 8 -
# -------------------------------------------------------
# Student Pair: L-160920ae:120ed3b11b6:-8000
#                 action timestamp                   cases  \
# 0   ** get new case **     0m 0s                       -
# 1               delete    0m 54s   1 3 5 7 9 | 3 4 5 6 7
# 2               delete    1m 13s   1 3 5 7 9 | 3 4 5 6 7
# 3               delete    3m 17s   1 3 5 7 9 | 3 4 5 6 7
# 4               submit    3m 31s   1 3 5 7 9 | 3 4 5 6 7
# 5   ** get new case **    4m 17s                       -
# 6               submit    6m 28s   1 3 5 7 9 | 1 4 5 6 9
# 7   ** get new case **     7m 2s                       -
# 8               submit    7m 44s      4 4 6 6 | 2 4 6 10
# 9   ** get new case **    8m 39s                       -
# 10              submit    9m 34s     2 4 6 10 | 2 5 6 10
# 11  ** get new case **    9m 58s                       -
# 12              delete   10m 26s  4 4 5 6 8 | 0 1 5 6 12
# 13              submit   11m 17s  4 4 5 6 8 | 0 1 5 6 12
# 14  ** get new case **   11m 30s                       -
# 15              submit   11m 53s      4 5 7 8 | 2 4 8 11
# 16  ** get new case **    12m 5s                       -
# 17              submit   12m 47s     2 5 8 | 2 2 5 5 8 8
# 18  ** get new case **    13m 3s                       -
# 19              submit   13m 35s     3 7 8 | 3 3 7 7 8 8
# 20  ** get new case **   13m 52s                       -
# 21              delete   14m 23s   1 3 5 7 9 | 1 2 3 3 9
# 22              submit   14m 59s   1 3 5 7 9 | 1 2 3 3 9
# 23  ** get new case **   15m 12s                       -
# 24              submit   15m 36s   5 5 5 11 | 11 11 11 5
# 25  ** get new case **   15m 50s                       -
#
#                 tried methods
# 0                           -
# 1         st1 9 - 1 st2 | st1
# 2   st1 9 - 1 st2 9 - 1 | st1
# 3   st1 9 - 1 st2 | st1 7 - 3
# 4      st1 9 - 1  | st1 7 - 3
# 5                           -
# 6       st1 7 - 3 | st1 6 - 4
# 7                           -
# 8      st1 6 - 4 | st1 10 - 2
# 9                           -
# 10      st1 6 - 4 | st1 6 - 5
# 11                          -
# 12     st1 8 - 4 | st1 12 - 0
# 13     st1 8 - 4 | st1 12 - 0
# 14                          -
# 15     st1 8 - 4 | st1 11 - 2
# 16                          -
# 17      st1 8 - 2 | st1 8 - 2
# 18                          -
# 19      st1 8 - 3 | st1 8 - 3
# 20                          -
# 21      st1 9 - 1 | st1 9 - 1
# 22      st1 7 - 3 | st1 3 - 2
# 23                          -
# 24    st1 11 - 5 | st1 11 - 5
# 25                          -
# -------------------------------------------------------
# Student Pair: L-2567b17a:120eda25685:-8000
#                 action timestamp                  cases  \
# 0   ** get new case **     0m 0s                      -
# 1               delete    0m 11s  1 3 5 7 9 | 3 4 5 6 7
# 2               submit    1m 44s  1 3 5 7 9 | 3 4 5 6 7
# 3               submit    2m 56s  1 3 5 7 9 | 3 4 5 6 7
# 4               delete    7m 31s  1 3 5 7 9 | 3 4 5 6 7
# 5               delete    7m 56s  1 3 5 7 9 | 3 4 5 6 7
# 6               delete    8m 43s  1 3 5 7 9 | 3 4 5 6 7
# 7               submit   10m 12s  1 3 5 7 9 | 3 4 5 6 7
# 8   ** get new case **   12m 11s                      -
# 9            deleteAll   15m 34s  1 3 5 7 9 | 1 4 5 6 9
# 10           deleteAll   15m 51s  1 3 5 7 9 | 1 4 5 6 9
# 11              delete   19m 38s  1 3 5 7 9 | 1 4 5 6 9
# 12              delete   21m 23s  1 3 5 7 9 | 1 4 5 6 9
# 13           deleteAll   21m 38s  1 3 5 7 9 | 1 4 5 6 9
# 14              submit   23m 23s  1 3 5 7 9 | 1 4 5 6 9
# 15           deleteAll   25m 18s  1 3 5 7 9 | 1 4 5 6 9
# 16              submit   26m 30s  1 3 5 7 9 | 1 4 5 6 9
# 17              submit   29m 42s  1 3 5 7 9 | 1 4 5 6 9
# 18              submit   31m 34s  1 3 5 7 9 | 1 4 5 6 9
# 19  ** get new case **   31m 45s                      -
#
#                                                                     tried methods
# 0                                                                               -
# 1                                                                     st1 9 | st1
# 2                                             st1 Average all  | st1 Average all
# 3                                             st1 Average all  | st1 Average all
# 4                                                 st1 Median all | st1 Median all
# 5                                                                   st1 Sum | st1
# 6                                                       st1 Sum all | st1 Sum all
# 7                                                           st1 9 - 1 | st1 7 - 3
# 8                                                                               -
# 9                                                 st1 Median all | st1 Median all
# 10                                              st1 Average all | st1 Average all
# 11                                  st1 9 - 1 st2 7 - 3 | st1 9 - 1 st2 6 - 4 st3
# 12  st1 9 - 1 st2 7 - 3 st3 Step1 - Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 - Step1
# 13  st1 9 - 1 st2 7 - 3 st3 Step1 - Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 - Step2
# 14  st1 9 - 1 st2 7 - 3 st3 Step1 - Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 - Step2
# 15                                                                st1 9 - 1 | st1
# 16  st1 9 - 1 st2 7 - 3 st3 Step1 - Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 - Step2
# 17  st1 9 + 1 st2 7 + 3 st3 Step1 + Step2 | st1 9 + 1 st2 6 + 4 st3 Step1 + Step2
# 18  st1 9 - 1 st2 7 - 3 st3 Step1 + Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 + Step2
# 19                                                                              -
# -------------------------------------------------------

# %% [markdown]
# # Plotting 16 pairs for analysis; condition Kand

# %%
# %aimport viz_utils 
session_pairs = ["L-23727b5d:120fc875dd6:-8000",
#                     "L-4af1736f:120fc85c498:-8000",
#                     "Ld1a3562:120fc85ee39:-8000",
#                     "L5cdf7922:120f1e34b2a:-8000",
#                     "L6203b1fe:120f1e535b4:-8000",
#                     "L-7fa003de:120f2365e41:-8000",
#                     "L4739cf0e:120f2367488:-8000",
#                     "L-3a693a9:120f818907f:-8000",
#                     "L-6425781a:120fcfdb07c:-8000",
#                     "L-7bb916cc:120f8188b5f:-8000",
#                     "L68f494a4:120fcfd39b6:-8000",
#                     "L-5bacd7a1:120edcb6ed9:-8000",
#                     "L-e22e239:120edcb3172:-8000",
#                     "L2a1d096a:120f7d9f5d3:-8000",
#                     "L45ac8b86:120f2b33c23:-8000",
                    "L6f07cfe6:120edcb473c:-8000"]



for session in session_pairs:
    print "Student Pair:", session
    df = prepare_session(df_all,session)
    plot(df,to_plot,colors, column_to_use, function_to_use)
    ideas = get_key_ideas(df)
    print "\n"
    display(ideas)
    print "\n\n\n-------------------------------------------------------"
# Out:
# Student Pair: L-23727b5d:120fc875dd6:-8000
#                 action timestamp                                  cases  \
# 0   ** get new case **     0m 0s                                      -
# 1               submit     1m 7s           44 47 50 53 | 44 45 45 46 53
# 2   ** get new case **    1m 40s                                      -
# 3               submit    2m 35s           45 48 51 | 45 45 48 48 51 51
# 4   ** get new case **    3m 20s                                      -
# 5               submit    7m 31s           46 50 51 | 46 46 50 50 51 51
# 6   ** get new case **    7m 49s                                      -
# 7            deleteAll    8m 52s  47 49 51 51 53 55 | 47 47 47 55 55 55
# 8               delete    11m 6s  47 49 51 51 53 55 | 47 47 47 55 55 55
# 9               delete   11m 45s  47 49 51 51 53 55 | 47 47 47 55 55 55
# 10              submit   12m 29s  47 49 51 51 53 55 | 47 47 47 55 55 55
#
#                                 tried methods
# 0                                           -
# 1   st1 Average all - 1 | st1 Average all - 1
# 2                                           -
# 3   st1 Average all - 2 | st1 Average all - 2
# 4                                           -
# 5   st1 Average all - 3 | st1 Average all - 3
# 6                                           -
# 7           st1 Median all  | st1 Median all
# 8           st1 Sum all - 4 | st1 Sum all - 5
# 9       st1 Sum all - 4 | st1 Average all - 4
# 10  st1 Average all - 4 | st1 Average all - 4
# -------------------------------------------------------
# Student Pair: L6f07cfe6:120edcb473c:-8000
#                action timestamp                                  cases  \
# 0  ** get new case **     0m 0s                                      -
# 1              submit    1m 24s           44 47 50 53 | 44 45 45 46 53
# 2  ** get new case **    1m 55s                                      -
# 3              delete    2m 50s        44 45 45 45 53 | 44 44 45 53 53
# 4              submit    5m 21s        44 45 45 45 53 | 44 44 45 53 53
# 5  ** get new case **    5m 40s                                      -
# 6              submit    7m 47s           46 50 51 | 46 46 50 50 51 51
# 7  ** get new case **   11m 29s                                      -
# 8           deleteAll   13m 39s  46 46 50 50 51 51 | 46 48 49 49 50 51
#
#                                                                       tried methods
# 0                                                                                 -
# 1   st1 10 - 1 st2 7 - 4 st3 Step1 + Step2 | st1 10 - 1 st2 3 - 2 st3 Step1 + Step2
# 2                                                                                 -
# 3                                                                  st1 10 - 2 | st1
# 4  st1 10 - 1 st2 2 - 2 st3 Step1 + Step2 | st1 10 - 1 st2 10 - 2 st3 Step1 + Step2
# 5                                                                                 -
# 6                                                             st1 8 - 3 | st1 8 - 3
# 7                                                                                 -
# 8           st1 8 + 3 st2 8 + 7 st3 7 + 3 st4 Step1 - Step2 st5 Step4 - Step3 | st1
# -------------------------------------------------------
