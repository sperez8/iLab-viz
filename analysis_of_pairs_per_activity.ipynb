# %%
# %load_ext autoreload
# %autoreload 1

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", 'This pattern has match groups')
# %matplotlib inline
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 60
pd.options.display.max_colwidth = 200

# %%
#utils.py is where all our custom functions live is we set an autoreload on it.
# %aimport utils 
from utils import *
# %aimport viz_utils 
from viz_utils import *

# %% [markdown]
# # Loading the data

# %%
df_all = pd.read_excel('all data v3.xlsx', 'iLab data.txt', index_col=None, na_values=['NA'])

# %% [markdown]
# # Plotting the 9 pairs for analysis; condition trampoline
# Along with the time coordinates of the ideas they had (i.e. their methods before a delete all or a submit)
#
# Note: students may have used a method multiple times, only the 1st time coordinate when the method was deleted/submitted is shown for simplicity.

# %%
# df[["Cleaned joined methods","Selection","Selection_unsided","Selection_unsided_shifted","Time_seconds"]]

# %%
# %aimport viz_utils
# %aimport utils
session_pairs = ["L70970875:120f77e742b:-8000",
    "L-32a989cf:120ecd7e93b:-8000",
    "L40bb98dd:120c3a7683a:-8000",
    "L-7821f52f:120f7fb42ba:-8000",
    "L651ef9df:120f7fb65f2:-8000",
    "L46c6b7c:120ed2665a4:-8000",
    "L-10f11766:120ecd4f63a:-8000",
    "L-160920ae:120ed3b11b6:-8000",
    "L-2567b17a:120eda25685:-8000"]

for session in session_pairs:
    print "Student Pair:", session
    df = prepare_session(df_all,session)
    plot(df,to_plot,colors, column_to_use, function_to_use)
    ideas = get_key_ideas(df)
    print "\n"
    display(ideas)
    print "\n\n\n-------------------------------------------------------"
# Out:
# Student Pair: L70970875:120f77e742b:-8000
#    action timestamp                        tried methods
# 0  delete   12m 44s       st1 Sum all  | st1 Count all +
# 1  submit   14m 34s    st1 Median all  | st1 Median all
# 2  submit   15m 53s  st1 Average all  | st1 Average all
# 3  submit   21m 33s  st1 Average all  | st1 Average all
# 4  submit   24m 40s    st1 - Median  | st1 - Median all
# 5  submit   26m 46s  st1 Average all  | st1 Average all
# -------------------------------------------------------
# Student Pair: L-32a989cf:120ecd7e93b:-8000
#        action timestamp  \
# 0      delete    1m 45s
# 1      delete    5m 30s
# 2   deleteAll    5m 54s
# 3      delete    7m 15s
# 4      delete    9m 18s
# 5      submit    9m 45s
# 6   deleteAll   14m 48s
# 7      delete    18m 8s
# 8   deleteAll   21m 37s
# 9   deleteAll   23m 45s
# 10  deleteAll    28m 4s
# 11  deleteAll   29m 15s
# 12  deleteAll    33m 1s
#
#                                                                                 tried methods
# 0                                                                      st1 Average all  | st1
# 1                                                                    st1 Median all + 5 | st1
# 2                                                               st1 Count choose... 5 9 | st1
# 3   st1 Median all x Average choose... 7 9 3 1  | st1 Median all x Average choose... 7 6 4 3
# 4                                                st1 Sum all + Average 1 3  | st1 Sum all + 3
# 5                                     st1 Sum all + Average 1 3  | st1 Sum all + Average 3 4
# 6                                     st1 Sum all + Average 2 5  | st1 Sum all + Average 2 2
# 7                                        st1 Count 2 5 x Count 8  | st1 Count choose... 2 2 5
# 8                             st1 Count 2 5 x Count 8  | st1 Count choose... 2 2 x Count 2 8
# 9                                         st1 Count 2 5 x Count 8  | st1 Count 2 2 x Count 8
# 10                                  st1 Median all / Count all  | st1 Median all / Count all
# 11                                st1 Median all / Count all  | st1 Median all / Count 2 5 8
# 12                st1 Sum all + Median all st2 Step1 x | st1 Sum all + Median all st2 Step1 x
# -------------------------------------------------------
# Student Pair: L40bb98dd:120c3a7683a:-8000
#       action timestamp  \
# 0     delete    0m 56s
# 1  deleteAll     1m 9s
# 2     delete    9m 13s
# 3     submit    10m 9s
# 4     delete   12m 38s
# 5     submit    13m 3s
# 6     delete   14m 23s
# 7     delete    16m 3s
# 8     submit   16m 18s
#
#                                                                                                              tried methods
# 0                                                                                                  st1 9 + 7 st2 5 | st1 7
# 1                                                                                                        st1 9 + 7 | st1 7
# 2                          st1 9 + 7 st2 Step1 + 3 st3 Step2 + 1 st4 Step3 / | st1 6 + 7 st2 Step1 + 5 st3 Step2 + 4 st4 3
# 3    st1 9 + 7 st2 Step1 + 3 st3 Step2 + 1 st4 Step3 / | st1 6 + 7 st2 Step1 + 5 st3 Step2 + 4 st4 Step3 + 3 st5 Step4 / 5
# 4                                            st1 8 + 5 st2 Step1 + 2 | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 5
# 5                              st1 8 + 5 st2 Step1 + 2 | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 2 st5 Step4 + 2
# 6              st1 8 + 5 st2 Step1 + 2 st3 | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 2 st5 Step4 + 2 st6 Step5 /
# 7        st1 8 + 5 st2 Step1 + 2 st3 5 / | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 2 st5 Step4 + 2 st6 Step5 / 5
# 8  st1 8 + 5 st2 Step1 + 2 st3 Step2 / 5 | st1 8 + 8 st2 Step1 + 5 st3 Step2 + 5 st4 Step3 + 2 st5 Step4 + 2 st6 Step5 / 5
# -------------------------------------------------------
# Student Pair: L-7821f52f:120f7fb42ba:-8000
#        action timestamp  \
# 0      delete    1m 48s
# 1      delete    2m 17s
# 2      delete    2m 42s
# 3   deleteAll     5m 9s
# 4      delete    9m 49s
# 5      delete   10m 42s
# 6      delete   19m 24s
# 7      delete   22m 27s
# 8      delete   23m 17s
# 9      delete   24m 39s
# 10  deleteAll   25m 15s
#
#                                                                                                                                                                                               tried methods
# 0                                                                                                                                                                                        st1 Sum 1 3  | st1
# 1                                                                                                                                                                                  st1 Average 7 3  | st1 7
# 2                                                                                                                                                                                  st1 Average all  | st1 7
# 3                                                                                                                            st1 Average all x 9 st2 Average all x 5 | st1 Average all x 7 st2 Average all
# 4                                         st1 Average all x 5 st2 Average all x 9 st3 Average all x 1 st4 Average all x 7 | st1 Average all x 6 st2 Average all x 7 st3 Sum all x 5 st4 Average all x Step3
# 5                                                                             st1 Average all x 5 st2 Average all x 9 st3 Average all x 1 st4 Average all x 7 | st1 Average all x 6 st2 Average all x 7 st3
# 6                                    st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 st4 Average all x 3 st5 | st1 Average all x 3 st2 Average all x 5 st3 Average all x 4 st4 Average all
# 7   st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 st4 Average all x 3 st5 Average all - 7 st6 Average all - 1 st7 Step1 - Step5 st8 | st1 Average all x 3 st2 Average all x 5 st3 Aver...
# 8   st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 st4 Average all x 3 st5 Average all - 7 st6 Average all - 1 st7 Step1 - Step5 st8 | st1 Average all x 3 st2 Average all x 5 st3 Aver...
# 9   st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 st4 Average all x 3 st5 Average all - 7 st6 Average all - 1 st7 Step1 - Step5 st8 Average all - 7 | st1 Average all x 3 st2 Average ...
# 10  st1 Average all x 1 st2 Average all x 9 st3 Sum Average all x 5 | st1 Average all x 3 st2 Average all x 5 st3 Average all x 4 st4 Average all - 5 st5 Average all - 7 st6 Average all - 6 st7 Averag...
# -------------------------------------------------------
# Student Pair: L651ef9df:120f7fb65f2:-8000
#        action timestamp                        tried methods
# 0      delete    0m 52s                        st1 1 + | st1
# 1   deleteAll    1m 17s                      st1 1 + 1 | st1
# 2      delete    2m 31s                          st1 1 | st1
# 3      delete    2m 59s                   st1 Sum all  | st1
# 4      delete     4m 6s  st1 Average all  | st1 Average all
# 5      delete    8m 22s                 st1 Count all  | st1
# 6      delete    8m 39s       st1 Count all  | st1 Count all
# 7      delete    9m 26s              st1 Average none  | st1
# 8      delete   10m 16s               st1 Average all  | st1
# 9      delete   10m 44s       st1 9 x 5 st2 Count all  | st1
# 10  deleteAll   10m 58s                      st1 9 x 9 | st1
# 11  deleteAll   11m 31s    st1 Median all  | st1 Median all
# 12  deleteAll    12m 3s          st1 Sum all  | st1 Sum all
# 13  deleteAll   12m 22s        st1 Count all  | st1 Sum all
# 14  deleteAll    13m 7s      st1 Average | st1 Average none
# 15  deleteAll   13m 30s  st1 Average all  | st1 Average all
# 16  deleteAll   13m 46s    st1 Median all  | st1 Median all
# 17  deleteAll   15m 45s                st1 9 - 1 | st1 7 - 4
# 18     submit   17m 19s                st1 9 - 1 | st1 7 - 3
# 19     submit   20m 32s                st1 9 - 1 | st1 7 - 3
# 20  deleteAll    22m 4s                st1 9 - 1 | st1 9 - 1
# 21  deleteAll   22m 26s  st1 Average all  | st1 Average all
# 22  deleteAll   22m 38s        st1 Count all | st1 Count all
# 23  deleteAll   22m 57s            st1 Sum all | st1 Sum all
# 24  deleteAll   23m 42s       st1 Median all  | st1 Sum all
# 25  deleteAll   24m 14s    st1 Median all  | st1 Median all
# -------------------------------------------------------
# Student Pair: L46c6b7c:120ed2665a4:-8000
#        action timestamp  \
# 0   deleteAll    3m 28s
# 1   deleteAll    5m 18s
# 2   deleteAll    6m 23s
# 3   deleteAll    6m 58s
# 4   deleteAll    7m 14s
# 5      delete    7m 35s
# 6   deleteAll    8m 16s
# 7      submit    8m 43s
# 8   deleteAll    9m 28s
# 9   deleteAll    9m 54s
# 10  deleteAll    10m 6s
# 11     submit   10m 34s
# 12  deleteAll   11m 44s
# 13  deleteAll   12m 30s
# 14  deleteAll   13m 40s
# 15     submit   15m 16s
# 16     submit   16m 54s
# 17  deleteAll   19m 47s
# 18  deleteAll   19m 59s
# 19     submit   20m 45s
# 20     submit   23m 24s
# 21  deleteAll   24m 20s
# 22     submit   24m 47s
# 23  deleteAll   25m 37s
# 24     submit   26m 26s
# 25     submit    31m 3s
#
#                                              tried methods
# 0                st1 Average choose... Median all  | st1 3
# 1                              st1 Sum all / 5 st2 | st1 3
# 2   st1 Sum all / 5 st2 | st1 Count choose... Median all x
# 3                   st1 Sum all / 5 st2 | st1 Median all x
# 4                              st1 Sum all / 5 st2 | st1 5
# 5                 st1 Sum all / 5 st2 | st1 Median all x 5
# 6                    st1 Sum all / 5 st2 | st1 Sum all / 5
# 7                        st1 Sum all / 5 | st1 Sum all / 5
# 8                    st1 Count choose... | st1 Sum all / 5
# 9                        st1 Count all x | st1 Sum all / 5
# 10                               st1 Sum | st1 Sum all / 5
# 11                       st1 Sum all / 5 | st1 Sum all / 5
# 12                   st1 Average all x 3 | st1 Sum all / 5
# 13                       st1 Sum all - 9 | st1 Sum all / 5
# 14                        st1 Count all  | st1 Sum all / 5
# 15                    st1 Count 2 4 6 8  | st1 Count none
# 16                 st1 Count 2 4 6 8  | st1 Count 3 2 8 7
# 17                                st1 Count 2 4 6 8  | st1
# 18                                     st1 Average 1 | st1
# 19               st1 Average choose... 4  | st1 Average 4
# 20                 st1 Count 2 4 6 8  | st1 Count 2 3 7 8
# 21                                       st1 Sum all | st1
# 22                       st1 Median all  | st1 Median all
# 23                                 st1 Sum 2 4 8 6 6 | st1
# 24               st1 Sum 4 6 8 2 / 5 | st1 Sum 7 8 3 2 / 5
# 25                     st1 Count 3 5 7  | st1 Count 4 5 6
# -------------------------------------------------------
# Student Pair: L-10f11766:120ecd4f63a:-8000
#        action timestamp  \
# 0   deleteAll    7m 50s
# 1   deleteAll   10m 16s
# 2   deleteAll   10m 32s
# 3   deleteAll   12m 19s
# 4   deleteAll   13m 45s
# 5   deleteAll    16m 2s
# 6      submit   20m 55s
# 7      submit    22m 7s
# 8   deleteAll   25m 20s
# 9      submit   25m 59s
# 10     submit   27m 11s
# 11  deleteAll   29m 38s
# 12  deleteAll   30m 56s
# 13  deleteAll   31m 10s
# 14  deleteAll   31m 18s
# 15     delete   31m 48s
# 16     delete    36m 8s
#
#                                                            tried methods
# 0                          st1 Average all / | st1 Average all / Average
# 1                                      st1 Median all  | st1 Median all
# 2                                        st1 Count all  | st1 Count all
# 3                                st1 Sum all / Count all  | st1 Sum all
# 4           st1 Average all / Median all | st1 Average all / Median all
# 5                                                  st1 Count all + | st1
# 6                                   st1 Count 2 4 6 8  | st1 Count none
# 7                                st1 Count 2 6 4 8  | st1 Count 3 2 7 8
# 8                                                            st1 2 | st1
# 9                                st1 Count 2 6 4 8  | st1 Count 3 2 7 8
# 10                               st1 Sum 1 3 5 7 9  | st1 Sum 1 4 5 6 9
# 11                   st1 Count choose... 2 4 6 8 + | st1 Sum 1 4 5 6 9 +
# 12             st1 Count choose... 2 4 6 8 + | st1 Count choose... 2 3 3
# 13                       st1 Count choose... 2 4 6 8 + | st1 Count 2 3 2
# 14                             st1 Count choose... 2 4 6 8 + | st1 Count
# 15                       st1 Count choose... 2 4 6 8 + | st1 Count 2 3 7
# 16  st1 Count choose... 2 4 6 8 - Count 1 3 5 7 9  | st1 Count 2 3 7 8 -
# -------------------------------------------------------
# Student Pair: L-160920ae:120ed3b11b6:-8000
#     action timestamp              tried methods
# 0   delete    0m 54s        st1 9 - 1 st2 | st1
# 1   delete    1m 13s  st1 9 - 1 st2 9 - 1 | st1
# 2   delete    3m 17s  st1 9 - 1 st2 | st1 7 - 3
# 3   submit    3m 31s     st1 9 - 1  | st1 7 - 3
# 4   submit    6m 28s      st1 7 - 3 | st1 6 - 4
# 5   submit    7m 44s     st1 6 - 4 | st1 10 - 2
# 6   submit    9m 34s      st1 6 - 4 | st1 6 - 5
# 7   delete   10m 26s     st1 8 - 4 | st1 12 - 0
# 8   submit   11m 17s     st1 8 - 4 | st1 12 - 0
# 9   submit   11m 53s     st1 8 - 4 | st1 11 - 2
# 10  submit   12m 47s      st1 8 - 2 | st1 8 - 2
# 11  submit   13m 35s      st1 8 - 3 | st1 8 - 3
# 12  delete   14m 23s      st1 9 - 1 | st1 9 - 1
# 13  submit   14m 59s      st1 7 - 3 | st1 3 - 2
# 14  submit   15m 36s    st1 11 - 5 | st1 11 - 5
# -------------------------------------------------------
# Student Pair: L-2567b17a:120eda25685:-8000
#        action timestamp  \
# 0      delete    0m 11s
# 1      submit    1m 44s
# 2      submit    2m 56s
# 3      delete    7m 31s
# 4      delete    7m 56s
# 5      delete    8m 43s
# 6      submit   10m 12s
# 7   deleteAll   15m 34s
# 8   deleteAll   15m 51s
# 9      delete   19m 38s
# 10     delete   21m 23s
# 11  deleteAll   21m 38s
# 12     submit   23m 23s
# 13  deleteAll   25m 18s
# 14     submit   26m 30s
# 15     submit   29m 42s
# 16     submit   31m 34s
#
#                                                                     tried methods
# 0                                                                     st1 9 | st1
# 1                                             st1 Average all  | st1 Average all
# 2                                             st1 Average all  | st1 Average all
# 3                                                 st1 Median all | st1 Median all
# 4                                                                   st1 Sum | st1
# 5                                                       st1 Sum all | st1 Sum all
# 6                                                           st1 9 - 1 | st1 7 - 3
# 7                                                 st1 Median all | st1 Median all
# 8                                               st1 Average all | st1 Average all
# 9                                   st1 9 - 1 st2 7 - 3 | st1 9 - 1 st2 6 - 4 st3
# 10  st1 9 - 1 st2 7 - 3 st3 Step1 - Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 - Step1
# 11  st1 9 - 1 st2 7 - 3 st3 Step1 - Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 - Step2
# 12  st1 9 - 1 st2 7 - 3 st3 Step1 - Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 - Step2
# 13                                                                st1 9 - 1 | st1
# 14  st1 9 - 1 st2 7 - 3 st3 Step1 - Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 - Step2
# 15  st1 9 + 1 st2 7 + 3 st3 Step1 + Step2 | st1 9 + 1 st2 6 + 4 st3 Step1 + Step2
# 16  st1 9 - 1 st2 7 - 3 st3 Step1 + Step2 | st1 9 - 1 st2 6 - 4 st3 Step1 + Step2
# -------------------------------------------------------

# %% [markdown]
# # Plotting 16 pairs for analysis; condition Kand

# %%
# %aimport viz_utils 
session_pairs = ["L-23727b5d:120fc875dd6:-8000",
                    "L-4af1736f:120fc85c498:-8000",
                    "Ld1a3562:120fc85ee39:-8000",
                    "L5cdf7922:120f1e34b2a:-8000",
                    "L6203b1fe:120f1e535b4:-8000",
                    "L-7fa003de:120f2365e41:-8000",
                    "L4739cf0e:120f2367488:-8000",
                    "L-3a693a9:120f818907f:-8000",
                    "L-6425781a:120fcfdb07c:-8000",
                    "L-7bb916cc:120f8188b5f:-8000",
                    "L68f494a4:120fcfd39b6:-8000",
                    "L-5bacd7a1:120edcb6ed9:-8000",
                    "L-e22e239:120edcb3172:-8000",
                    "L2a1d096a:120f7d9f5d3:-8000",
                    "L45ac8b86:120f2b33c23:-8000",
                    "L6f07cfe6:120edcb473c:-8000"]



for session in session_pairs:
    print "Student Pair:", session
    df = prepare_session(df_all,session)
    plot(df,to_plot,colors, column_to_use, function_to_use)
    ideas = get_key_ideas(df)
    print "\n"
    display(ideas)
    print "\n\n\n-------------------------------------------------------"
# Out:
# Student Pair: L-23727b5d:120fc875dd6:-8000
#       action timestamp                              tried methods
# 0     submit     1m 7s  st1 Average all - 1 | st1 Average all - 1
# 1     submit    2m 35s  st1 Average all - 2 | st1 Average all - 2
# 2     submit    7m 31s  st1 Average all - 3 | st1 Average all - 3
# 3  deleteAll    8m 52s          st1 Median all  | st1 Median all
# 4     delete    11m 6s          st1 Sum all - 4 | st1 Sum all - 5
# 5     delete   11m 45s      st1 Sum all - 4 | st1 Average all - 4
# 6     submit   12m 29s  st1 Average all - 4 | st1 Average all - 4
# -------------------------------------------------------
# Student Pair: L-4af1736f:120fc85c498:-8000
#        action timestamp  \
# 0   deleteAll    0m 59s
# 1      submit    2m 58s
# 2   deleteAll    4m 45s
# 3   deleteAll    5m 31s
# 4   deleteAll    6m 34s
# 5   deleteAll    8m 14s
# 6      delete   11m 45s
# 7   deleteAll   12m 28s
# 8   deleteAll   12m 53s
# 9   deleteAll   13m 21s
# 10  deleteAll   13m 36s
# 11  deleteAll    14m 0s
#
#                                                    tried methods
# 0                            st1 Average all - Median all  | st1
# 1    st1 Count all + Average all  | st1 Count all + Average all
# 2   st1 Count all - Average all  | st1 Median all - Average all
# 3    st1 Count all - Average all  | st1 Count all - Average all
# 4    st1 Count all - Average all  | st1 Count all - Average all
# 5                  st1 Count all - Average all  | st1 Count all
# 6    st1 Count all - Average all  | st1 Count all - Average all
# 7    st1 Average all - Count all  | st1 Count all - Average all
# 8   st1 Average all - Median all  | st1 Count all - Average all
# 9     st1 Median all - Count all  | st1 Count all - Average all
# 10                    st1 Median all - Count all  | st1 Sum all
# 11    st1 Median all - Count all  | st1 Average all - Count all
# -------------------------------------------------------
# Student Pair: Ld1a3562:120fc85ee39:-8000
#       action timestamp  \
# 0  deleteAll    0m 16s
# 1  deleteAll    1m 28s
# 2  deleteAll    2m 53s
# 3     delete   12m 13s
# 4     delete   12m 38s
#
#                                                                    tried methods
# 0                                                                  st1 Sum | st1
# 1                                    st1 Sum all + 10 st2 Average all / 10 | st1
# 2  st1 Sum all + 10 st2 Average all / 10 | st1 Sum all + 10 st2 Average all / 10
# 3                                                         st1 Count 2 3 | st1 13
# 4                                                             st1 4 - 1 | st1 13
# -------------------------------------------------------
# Student Pair: L5cdf7922:120f1e34b2a:-8000
#        action timestamp  \
# 0   deleteAll     0m 6s
# 1   deleteAll    0m 21s
# 2      delete     2m 0s
# 3      delete     4m 3s
# 4      delete    4m 16s
# 5      submit    4m 44s
# 6      submit    6m 25s
# 7      delete     8m 2s
# 8   deleteAll    8m 27s
# 9   deleteAll    9m 26s
# 10  deleteAll   10m 23s
# 11  deleteAll   10m 52s
# 12     submit    14m 8s
#
#                                                                                     tried methods
# 0                                                                                     st1 2 | st1
# 1                                                                             st1 Count 2 5 | st1
# 2             st1 Count 2 3 5 6 8 9 - Count 1 4 7 10  | st1 Count 4 5 6 7 8 9 - Count 1 2 2 3 10
# 3   st1 Count choose... 2 3 5 6 8 9 + Count 1 4 7 10  | st1 Count 4 5 6 7 8 9 - Count 1 2 2 3 10
# 4                                 st1 Count choose... 2 3 5 6 8 9 + Count 1 4 7 10  | st1 Count 1
# 5   st1 Count choose... 2 3 5 6 8 9 + Count 1 4 7 10  | st1 Count 4 5 6 7 8 9 + Count 2 1 2 3 10
# 6               st1 Count 2 3 5 6 8 9 + Count 1 4 7 10  | st1 Count 2 3 4 7 8 9 + Count 1 5 6 10
# 7                                          st1 Count Average 1 4 7 10 - Average 2 3 5 6 8 9 | st1
# 8                                                              st1 Average all  | st1 Average all
# 9                                                      st1 Count all - Count all  | st1 Sum all -
# 10                                                                             st1 Count 10 | st1
# 11                                                                            st1 10 - 1 | st1 10
# 12                                              st1 Count 1 2 4  | st1 Count 2 3 4 4 4 8 9 10 12
# -------------------------------------------------------
# Student Pair: L6203b1fe:120f1e535b4:-8000
#       action timestamp  \
# 0     submit    1m 25s
# 1  deleteAll    3m 23s
# 2  deleteAll    4m 15s
# 3     submit    4m 25s
# 4  deleteAll    8m 21s
# 5     delete   10m 49s
# 6     delete   11m 14s
#
#                                                                                                                                           tried methods
# 0                                                                                               st1 Average all / Sum all  | st1 Average all / Sum all
# 1                                                                                               st1 Average all / Sum all  | st1 Average all / Sum all
# 2                                                                                                                st1 8 - 5 | st1 Average all / Sum all
# 3                                                                                                                                 st1 8 - 5 | st1 8 - 5
# 4  st1 Sum all - 10 st2 Step1 - 9 st3 Step2 - 8 st4 Step3 - 4 st5 Step4 - 3 | st1 Sum all - 12 st2 Step1 10 - st3 Step2 - 8 st4 Step3 - 4 st5 Step4 - 1
# 5                                            st1 Average all - 10 st2 Step1 - 9 st3 Step2 - 8 st4 Step3 - 4 st5 Step4 - 3 | st1 all - 12 st2 Step1 - 10
# 6                                  st1 Average all - 10 st2 Step1 - 9 st3 Step2 - 8 st4 Step3 - 4 st5 Step4 - 3 | st1 all - 12 st2 Step1 - 10 st3 Step1
# -------------------------------------------------------
# Student Pair: L-7fa003de:120f2365e41:-8000
#        action timestamp                   tried methods
# 0      submit    0m 26s           st1 7 - 4 | st1 3 - 2
# 1      submit    1m 22s         st1 14 - 2 | st1 10 - 1
# 2   deleteAll    1m 56s                    st1 14 | st1
# 3      submit    2m 19s          st1 12 - 4 | st1 9 - 6
# 4      submit    3m 15s          st1 11 - 0 | st1 9 - 5
# 5      submit    3m 53s           st1 9 - 6 | st1 9 - 7
# 6      submit    4m 36s          st1 9 - 7 | st1 12 - 4
# 7      submit    5m 23s         st1 11 - 8 | st1 14 - 2
# 8      submit    6m 11s         st1 11 - 8 | st1 13 - 4
# 9      submit    6m 58s           st1 8 - 2 | st1 8 - 2
# 10     submit    7m 56s           st1 8 - 3 | st1 8 - 3
# 11     delete    9m 15s          st1 8 - 6 | st1 10 - 6
# 12  deleteAll   10m 23s  st1 10 + 8 st2 8 + 6 st3 | st1
# 13     delete   11m 30s           st1 8 - 8 | st1 8 - 6
# 14  deleteAll   12m 24s           st1 8 - 8 | st1 8 - 6
# -------------------------------------------------------
# Student Pair: L4739cf0e:120f2367488:-8000
#       action timestamp  \
# 0     submit    0m 26s
# 1     submit    1m 42s
# 2  deleteAll     5m 0s
# 3     submit    6m 39s
# 4     submit    7m 50s
# 5     submit    8m 42s
# 6     submit   10m 34s
# 7     submit   11m 20s
# 8  deleteAll    12m 8s
# 9     submit   13m 43s
#
#                                                        tried methods
# 0                                              st1 7 - 1 | st1 3 - 1
# 1                                              st1 3 - 1 | st1 9 - 1
# 2                                     st1 Sum 3 1 1  | st1 Sum 1 3 3
# 3                                              st1 9 - 1 | st1 9 - 3
# 4                                              st1 7 - 3 | st1 8 - 3
# 5                                              st1 8 - 2 | st1 8 - 2
# 6                                              st1 5 - 2 | st1 6 - 4
# 7                                            st1 10 - 3 | st1 12 - 1
# 8                                              st1 8 + 3 | st1 8 + 3
# 9  st1 Average all / Count 3 7 8  | st1 Average 3 7 8 / Count 3 7 8
# -------------------------------------------------------
# Student Pair: L-3a693a9:120f818907f:-8000
#       action timestamp  \
# 0     delete    3m 37s
# 1     delete    4m 21s
# 2  deleteAll    7m 54s
# 3  deleteAll    9m 12s
# 4     delete   10m 47s
#
#                                                                              tried methods
# 0               st1 Average all - 10 st2 7 - 1 st3 | st1 Average all - 10 st2 Average all
# 1  st1 Average all - 10 st2 7 - 1 st3 Average all  | st1 Average all - 10 st2 Average all
# 2                             st1 Average all - 10 | st1 Average all - 10 st2 Average all
# 3                                          st1 Average all - 10 | st1 Average all - 10 st2
# 4                 st1 Average all - 10 st2 7 - 1 st3 | st1 Average all - 10 st2 12 - 3 st3
# -------------------------------------------------------
# Student Pair: L-6425781a:120fcfdb07c:-8000
#    action timestamp  \
# 0  delete    1m 55s
# 1  delete    4m 58s
# 2  delete    7m 28s
# 3  delete    8m 52s
# 4  delete   16m 32s
# 5  submit   17m 53s
#
#                                                                                                                                                                                              tried methods
# 0                                                                                                                       st1 Average all - 10 st2 Average all - 4 | st1 Average all - 3 st2 Average all - 3
# 1                                                                               st1 Average all - 10 st2 Average all - 4 st3 Average all - 10 | st1 Average all - 3 st2 Average all - 10 st3 Average all 3
# 2                st1 Average all - 10 st2 Average all - 4 st3 Average all - 10 st4 Average all - 1 st5 Average all  | st1 Average all - 3 st2 Average all - 10 st3 Average all - 1 st4 Average all - 2 st5
# 3                                               st1 Average all - 10 st2 Average all - 4 st3 Average all - 10 | st1 Average all - 3 st2 Average all - 10 st3 Average all - 1 st4 Average all - 2 st5 2 - 1
# 4  st1 Average all - 10 st2 Average all - 4 st3 Average all - 10 st4 Average all - 7 st5 10 - 1 st6 Step1 + Step5 st7 Step6 + Step4 | st1 Average all - 3 st2 Average all - 10 st3 Average all - 1 st4 ...
# 5  st1 Average all - 10 st2 Average all - 4 st3 Average all - 10 st4 Average all - 7 st5 10 - 1 st6 Step1 + Step5 st7 Step6 + Step4 st8 Step7 + Step2 st9 Step8 + Step3 | st1 Average all - 3 st2 Avera...
# -------------------------------------------------------
# Student Pair: L-7bb916cc:120f8188b5f:-8000
#        action timestamp                      tried methods
# 0   deleteAll    1m 43s     st1 Count all | st1 Count all
# 1      delete    2m 55s                   st1 10 - 1 | st1
# 2      submit    3m 16s              st1 7 - 1 | st1 3 - 1
# 3      submit    4m 56s              st1 3 - 1 | st1 9 - 1
# 4      submit    6m 12s              st1 3 - 1 | st1 9 - 1
# 5   deleteAll     7m 5s                    st1 9 - 1 | st1
# 6   deleteAll    7m 25s          st1 Count all | st1 Count
# 7   deleteAll    8m 29s    st1 Median all | st1 Median all
# 8      submit    9m 28s  st1 Median all  | st1 Median all
# 9   deleteAll   12m 30s    st1 Median all | st1 Median all
# 10  deleteAll   12m 44s  st1 Average all | st1 Average all
# 11     submit    13m 5s        st1 Sum all  | st1 Sum all
# -------------------------------------------------------
# Student Pair: L68f494a4:120fcfd39b6:-8000
#        action timestamp                                    tried methods
# 0   deleteAll    0m 33s                            st1 4 - 1 | st1 2 - 1
# 1      submit    1m 17s                            st1 4 - 1 | st1 2 - 1
# 2      submit    1m 50s                          st1 14 - 1 | st1 12 - 1
# 3      submit    2m 23s                            st1 3 - 1 | st1 5 - 1
# 4      submit     3m 2s                           st1 5 - 1 | st1 10 - 1
# 5      submit    3m 41s                            st1 5 - 1 | st1 3 - 1
# 6      submit    4m 10s                           st1 8 - 1 | st1 13 - 1
# 7   deleteAll    4m 35s                                    st1 8 - | st1
# 8      submit    4m 57s                            st1 4 - 1 | st1 2 - 1
# 9   deleteAll    6m 19s                        st1 8 - 2 | st1 8 - 2 st2
# 10     submit     7m 7s                  st1 Count all  | st1 Count all
# 11     submit     8m 7s                  st1 Count all  | st1 Count all
# 12     submit    9m 25s                  st1 Count all  | st1 Count all
# 13     submit    9m 53s              st1 Average all  | st1 Average all
# 14  deleteAll   10m 28s                   st1 Sum all  | st1 Average all
# 15     submit   10m 38s              st1 Average all  | st1 Average all
# 16     submit   11m 15s                  st1 Count all  | st1 Count all
# 17  deleteAll    12m 3s                  st1 Count all  | st1 Count all
# 18  deleteAll   12m 18s              st1 Average all  | st1 Average all
# 19  deleteAll   12m 46s                st1 Median all  | st1 Median all
# 20  deleteAll   13m 18s  st1 Average choose... Count all  | st1 Sum all
# 21  deleteAll   14m 29s                      st1 11 - 9 | st1 11 - 9 st2
# 22  deleteAll   14m 56s                                      st1 9 | st1
# 23  deleteAll   15m 25s                  st1 Count all  | st1 Count all
# 24  deleteAll   17m 27s                              st1 11 + 6 | st1 11
# 25  deleteAll   18m 42s                          st1 9 x 9 | st1 11 x 11
# -------------------------------------------------------
# Student Pair: L-5bacd7a1:120edcb6ed9:-8000
#        action timestamp            tried methods
# 0      delete    0m 20s           st1 10 - | st1
# 1      submit     2m 7s    st1 7 - 4 | st1 3 - 2
# 2      submit     3m 2s  st1 13 - 2 | st1 10 - 2
# 3      submit     4m 0s   st1 12 - 3 | st1 9 - 6
# 4      submit    4m 29s   st1 9 - 6 | st1 12 - 3
# 5      submit     6m 7s    st1 9 - 6 | st1 8 - 7
# 6      submit    6m 39s  st1 13 - 7 | st1 14 - 0
# 7   deleteAll    7m 36s        st1 13 - 11 | st1
# 8      submit    7m 57s  st1 11 - 9 | st1 12 - 8
# 9      submit    8m 37s  st1 10 - 3 | st1 12 - 1
# 10     submit    9m 29s    st1 8 - 2 | st1 8 - 2
# 11     submit   10m 12s    st1 8 - 3 | st1 8 - 3
# 12  deleteAll   11m 24s  st1 11 - 5 | st1 11 - 9
# 13  deleteAll   12m 45s           st1 11 - | st1
# -------------------------------------------------------
# Student Pair: L-e22e239:120edcb3172:-8000
#       action timestamp                        tried methods
# 0     submit    0m 34s              st1 10 - 1 | st1 10 - 1
# 1     submit    2m 30s  st1 Average all  | st1 Average all
# 2  deleteAll    4m 54s  st1 Average all  | st1 Average all
# 3     submit    5m 54s              st1 14 - 5 | st1 10 - 1
# 4     submit    8m 54s                st1 3 - 2 | st1 3 - 3
# 5     submit   10m 27s              st1 11 - 3 | st1 14 - 3
# 6     submit   12m 23s    st1 Median all  | st1 Median all
# -------------------------------------------------------
# Student Pair: L2a1d096a:120f7d9f5d3:-8000
#        action timestamp                        tried methods
# 0      submit    1m 10s    st1 Median all  | st1 Median all
# 1      submit     2m 5s    st1 Median all  | st1 Median all
# 2      submit    2m 53s    st1 Median all  | st1 Median all
# 3      submit    3m 57s    st1 Median all  | st1 Median all
# 4   deleteAll     5m 4s    st1 Median all  | st1 Median all
# 5   deleteAll    5m 33s  st1 Average all  | st1 Average all
# 6   deleteAll    5m 52s     st1 Count all | st1 Average all
# 7   deleteAll    6m 11s        st1 Count all | st1 Count all
# 8   deleteAll    6m 39s          st1 Sum all  | st1 Sum all
# 9   deleteAll    8m 11s                  st1 10 / 2 | st1 10
# 10     submit   11m 18s                st1 6 - 6 | st1 7 - 5
# 11  deleteAll   12m 11s                          st1 6 | st1
# 12     submit   13m 10s  st1 Average all  | st1 Average all
# 13  deleteAll    14m 6s  st1 Average all  | st1 Average all
# 14  deleteAll   14m 58s     st1 Median all  | st1 Median all
# 15     submit   15m 55s              st1 12 - 10 | st1 8 - 6
# 16     submit    17m 8s              st1 10 - 3 | st1 12 - 1
# -------------------------------------------------------
# Student Pair: L45ac8b86:120f2b33c23:-8000
#       action timestamp  \
# 0     submit    1m 19s
# 1     delete    2m 23s
# 2     delete    3m 48s
# 3  deleteAll    4m 12s
# 4     submit     6m 7s
# 5     submit    8m 28s
# 6     submit   11m 29s
#
#                                                                        tried methods
# 0    st1 10 - 1 st2 7 - 4 st3 Step1 + Step2 | st1 10 - 1 st2 3 - 2 st3 Step1 + Step2
# 1                                                             st1 10 - 1 st2 3 | st1
# 2  st1 10 - 1 st2 10 - 2 st3 Step1 + Step2 | st1 10 - 1 st2 10 - 2 st3 Step1 + Step2
# 3                                      st1 10 - 1 st2 10 - 2 | st1 10 - 1 st2 10 - 2
# 4   st1 10 - 1 st2 2 - 2 st3 Step1 + Step2 | st1 10 - 1 st2 10 - 1 st3 Step1 + Step2
# 5      st1 3 - 1 st2 2 - 1 st3 Step1 + Step2 | st1 8 - 1 st2 2 - 1 st3 Step1 + Step2
# 6      st1 3 - 1 st2 2 - 2 st3 Step1 + Step2 | st1 3 - 1 st2 3 - 1 st3 Step1 + Step2
# -------------------------------------------------------
# Student Pair: L6f07cfe6:120edcb473c:-8000
#       action timestamp  \
# 0     submit    1m 24s
# 1     delete    2m 50s
# 2     submit    5m 21s
# 3     submit    7m 47s
# 4  deleteAll   13m 39s
#
#                                                                       tried methods
# 0   st1 10 - 1 st2 7 - 4 st3 Step1 + Step2 | st1 10 - 1 st2 3 - 2 st3 Step1 + Step2
# 1                                                                  st1 10 - 2 | st1
# 2  st1 10 - 1 st2 2 - 2 st3 Step1 + Step2 | st1 10 - 1 st2 10 - 2 st3 Step1 + Step2
# 3                                                             st1 8 - 3 | st1 8 - 3
# 4           st1 8 + 3 st2 8 + 7 st3 7 + 3 st4 Step1 - Step2 st5 Step4 - Step3 | st1
# -------------------------------------------------------
